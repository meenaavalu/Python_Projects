# %% [markdown]
# # Predicting Churn Customers

# %% [markdown]
# Context:
#
# The project aims to analyze customer churn using a dataset containing customer demographics, credit behavior, and transaction history. The key steps include:
#
# Data Loading & Preprocessing: Cleaning data by removing unnecessary columns, checking for missing values and duplicates.
#
# Exploratory Data Analysis (EDA): Analyzing distributions of customer attributes like age, gender, education, marital status, and income category.
#
# Statistical Insights: Identifying trends and correlations, such as the negative relationship between credit limit and utilization ratio.
#
# Feature Engineering & Model Building: Preparing data for machine learning, selecting features, and applying predictive models.

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
# Data processing
import numpy as np # linear algebra
import pandas as pd # data processing

# Data visuals
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Encoder
from sklearn.preprocessing import OrdinalEncoder

# ML classifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
import sklearn.model_selection as ms
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier

# to split dataset to train and test
from sklearn.model_selection import train_test_split

# ML classifier model Evaluation
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# scaling 
from sklearn.preprocessing import StandardScaler

# to tune the model parameters
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# To balance the over sampling we are using SMOTE
from imblearn.over_sampling import SMOTE

# Gradient Boosting classifier
from sklearn.ensemble import GradientBoostingClassifier

# XG Boost Classifier
import xgboost as xgb

# %% [markdown]
# # Loading The Dataset

# %%
df=pd.read_csv("BankChurners.csv")
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# # Metadata Of Dataframe

# %%
# Checking the number of rows and columns
df.shape
# Out:
# (10127, 23)

# %% [markdown]
# Removing client number column because it is not necessary for analysis as it is a unique id

# %%
# Dropping the last two columns and the client number column
df = df.iloc[:,1:-2]

# %%
# After dropping the shape of the dataset 
df.shape
# Out:
# (10127, 20)

# %%
#The columns in the dataset
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %% [raw]
# There are 20 columns in the Dataset after dropping client number

# %%
#The data types of the columns
df.dtypes
# Out:
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %% [markdown]
# # Cleaning the Data

# %% [markdown]
# ## Checking NAN Values

# %%
# To know the number of NaN Values
nan_indices = df.isna().sum() 
print(nan_indices)
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# There is no NaN Values in the Dataset

# %% [markdown]
# ## Finding the duplicates from dataset

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Attrition_Flag, Customer_Age, Gender, Dependent_count, Education_Level, Marital_Status, Income_Category, Card_Category, Months_on_book, Total_Relationship_Count, Months_Inactive_12_mon, Contacts_Count_12_mon, Credit_Limit, Total_Revolving_Bal, Avg_Open_To_Buy, Total_Amt_Chng_Q4_Q1, Total_Trans_Amt, Total_Trans_Ct, Total_Ct_Chng_Q4_Q1, Avg_Utilization_Ratio]
# Index: []

# %% [markdown]
# There is no duplicates in the dataset

# %% [markdown]
# # Statistical View of the Data

# %% [markdown]
# ## Statistics of the numerical columns

# %%
# Checking the statistics of the numerical columns
stats = df.describe(exclude = 'object')
print(stats)
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# ...

# %% [raw]
# 1. The average customer age is 46 years old. Most customers are concentrated between 41-52 years old based on the quantiles.
# 2. Customers have an average of 2 dependents, with most having 1-3 dependents.
# 3. The average relationship length is almost 36 months. Most relationships are 2-4 years long.
# 4. Customers have an average of 4 total relationships with the bank and are inactive for 2 months out of the last 12 on average.
# 5. Customers have around 2-3 contacts on average over 12 months.
# 6. The average credit limit is $8631, but there is large variability. Most customers fall between $2500 - $11000 credit limit.
# 7. Average revolving balance is around $1100. Median is higher at $1300, showing some higher balances.
# 8. Customers seem to be using 27% of their available credit on average. But there is high variability in utilization ratios.
# 9. Average quarterly change in transaction amount is 0.76x while number of transactions changes by 0.71x. This indicates moderate growth in activity.
# 10. Average yearly transaction amount is $4400 and customers have 65 transactions per year. So transaction size is moderate.

# %% [markdown]
# ## Statistics of the Categorical data

# %%
# Statistics on Categorical data
stats_cat = df.describe(exclude = ['float', 'int64'])
print(stats_cat)
# Out:
#            Attrition_Flag Gender Education_Level Marital_Status  \
# count               10127  10127           10127          10127
# unique                  2      2               7              4
# top     Existing Customer      F        Graduate        Married
# freq                 8500   5358            3128           4687
#
#        Income_Category Card_Category
# count            10127         10127
# unique               6             4
# top     Less than $40K          Blue
# freq              3561          9436

# %% [raw]
# 1. For Attrition_Flag, the majority (8500 out of 10127) are existing customers. This indicates most customers are retained.
# 2. Gender is split between Female (5358) and Male (4769). Fairly even distribution.
# 3. Most common Education Level is Graduate (3128 customers).
# 4. Majority of customers are Married (4687).
# 5. The largest Income Category is Less than $40K (3561 customers).
# 6. Most customers have a Blue credit card (9436).

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Exploring Target Variable

# %%
target_df = df['Attrition_Flag'].value_counts().reset_index()
target_df.columns = ['Customer status','Count']
print(target_df)
# Out:
#      Customer status  Count
# 0  Existing Customer   8500
# 1  Attrited Customer   1627

# %%
#PieChart
Customer_status = ['Existing Customer','Attrited Customer']
fig, ax = plt.subplots(figsize=(10,5))
ax.pie(target_df['Count'], labels=Customer_status, autopct='%1.1f%%')
fig.show()
# Out:
# C:\Users\meena\AppData\Local\Temp\ipykernel_49036\2542248661.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plt.figure(figsize = (20,5))
plt.title('Number of existing customer and customer who left');
countplt = sns.countplot(x='Attrition_Flag', data=df)

# %% [raw]
# Of the 10127 customers, 8500 are current customers, and 1627 are attrition customers.

# %% [markdown]
# ## Exploring Customer Age

# %%
bins = [18, 30, 40, 50, 60, 70, 110]
labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70+']
age = pd.cut(df['Customer_Age'], bins, labels=labels, include_lowest=True)
sns.countplot(x=age, palette='winter', hue=age)
plt.title('Customer Age Group')
plt.show()

# %%
_box=sns.boxplot(data = df,x='Attrition_Flag',y='Customer_Age')

# %%
# Customer Age
left_customer = df[df['Attrition_Flag']=='Attrited Customer']
Existing_Customer = df[df['Attrition_Flag']=='Existing Customer']

print('Stats of Existing Customer Age',round(Existing_Customer['Customer_Age'].describe(),2))
print('Stats of Attrited Customer Age',round(left_customer['Customer_Age'].describe(),2))
# Out:
# Stats of Existing Customer Age count    8500.00
# mean       46.26
# std         8.08
# min        26.00
# 25%        41.00
# 50%        46.00
# 75%        52.00
# max        73.00
# Name: Customer_Age, dtype: float64
# Stats of Attrited Customer Age count    1627.00
# mean       46.66
# std         7.67
# min        26.00
# 25%        41.00
# 50%        47.00
# 75%        52.00
# max        68.00
# Name: Customer_Age, dtype: float64

# %% [raw]
# Most of the customer who left the credit card service is from 40 to 50 age group. And the Minimum age group of the customer is 26 and the max age of the existing customer is 73 and max age of the attrited customer is 68.

# %% [markdown]
# ## Exploring the Gender

# %%
target_df = df['Gender'].value_counts().reset_index()
target_df.columns = ['Gender','Count']
print(target_df)
# Out:
#   Gender  Count
# 0      F   5358
# 1      M   4769

# %%
plt.figure(figsize = (15,5))
countplt = sns.countplot(x='Gender', data=df)
plt.title('Gender of the customer');

# %% [raw]
# The plot shows the Gender and number of customers using credit card service, of that 5358 are female customers and 4769 are male customers.

# %%
#countplot
plt.figure(figsize = (15,5))
plt.title("Gender with Churned or not")
sns.countplot(data = df, x = df["Gender"], hue = "Attrition_Flag")
# Out:
# <Axes: title={'center': 'Gender with Churned or not'}, xlabel='Gender', ylabel='count'>

# %% [raw]
# THe plot show the the number of customers who left the credit card service and their Gender. We can see there is a high number of female customer leaving the card service.

# %% [markdown]
# ## Exploring Education Level

# %%
target_df = df['Education_Level'].value_counts().reset_index()
target_df.columns = ['Education_Level','Count']
print(target_df)
# Out:
#   Education_Level  Count
# 0        Graduate   3128
# 1     High School   2013
# 2         Unknown   1519
# 3      Uneducated   1487
# 4         College   1013
# 5   Post-Graduate    516
# 6       Doctorate    451

# %%
# Churn rate by education level 
df.groupby('Education_Level')['Attrition_Flag'].value_counts()
# Out:
# Education_Level  Attrition_Flag
# College          Existing Customer     859
#                  Attrited Customer     154
# Doctorate        Existing Customer     356
#                  Attrited Customer      95
# Graduate         Existing Customer    2641
#                  Attrited Customer     487
# High School      Existing Customer    1707
#                  Attrited Customer     306
# Post-Graduate    Existing Customer     424
#                  Attrited Customer      92
# Uneducated       Existing Customer    1250
#                  Attrited Customer     237
# Unknown          Existing Customer    1263
#                  Attrited Customer     256
# Name: Attrition_Flag, dtype: int64

# %%
#countplot
plt.figure(figsize = (15,5))
plt.title("Education Level with Churned or not", fontsize = 20)
sns.countplot(data =df, x = "Education_Level", hue = "Attrition_Flag")
# Out:
# <Axes: title={'center': 'Education Level with Churned or not'}, xlabel='Education_Level', ylabel='count'>

# %% [raw]
# The plot displays the credit card service customers along with their educational backgrounds; the majority are graduates. Additionally, it demonstrates that the customer who cancelled their credit card service had a graduate degree.

# %% [markdown]
# ## Exploring Marriage Status

# %%
target_df = df['Marital_Status'].value_counts().reset_index()
target_df.columns = ['Marital_Status','Count']
print(target_df)
# Out:
#   Marital_Status  Count
# 0        Married   4687
# 1         Single   3943
# 2        Unknown    749
# 3       Divorced    748

# %%
# Churn rate by Marriage Status 
df.groupby('Marital_Status')['Attrition_Flag'].value_counts("percentage")
# Out:
# Marital_Status  Attrition_Flag
# Divorced        Existing Customer    0.838235
#                 Attrited Customer    0.161765
# Married         Existing Customer    0.848731
#                 Attrited Customer    0.151269
# Single          Existing Customer    0.830586
#                 Attrited Customer    0.169414
# Unknown         Existing Customer    0.827770
#                 Attrited Customer    0.172230
# Name: Attrition_Flag, dtype: float64

# %% [raw]
# Comparing married status to the other statuses, there is a slight decrease in churn risk. However, the overall impact in this data is negligible.

# %% [markdown]
# ## Exploring Income Category

# %%
target_df = df['Income_Category'].value_counts().reset_index()
target_df.columns = ['Income_Category','Count']
print(target_df)
# Out:
#   Income_Category  Count
# 0  Less than $40K   3561
# 1     $40K - $60K   1790
# 2    $80K - $120K   1535
# 3     $60K - $80K   1402
# 4         Unknown   1112
# 5         $120K +    727

# %%
# Churn rate by income category
df.groupby('Income_Category')['Attrition_Flag'].value_counts()
# Out:
# Income_Category  Attrition_Flag
# $120K +          Existing Customer     601
#                  Attrited Customer     126
# $40K - $60K      Existing Customer    1519
#                  Attrited Customer     271
# $60K - $80K      Existing Customer    1213
#                  Attrited Customer     189
# $80K - $120K     Existing Customer    1293
#                  Attrited Customer     242
# Less than $40K   Existing Customer    2949
#                  Attrited Customer     612
# Unknown          Existing Customer     925
#                  Attrited Customer     187
# Name: Attrition_Flag, dtype: int64

# %%
plt.figure(figsize = (15,5))
plt.title("Income Category of Customers", fontsize = 30)
sns.countplot(x=df['Income_Category'],hue=df['Attrition_Flag'])
# Out:
# <Axes: title={'center': 'Income Category of Customers'}, xlabel='Income_Category', ylabel='count'>

# %% [raw]
# The customer income category is plotted, and the majority of customers fall into the category of less than $40000, which also has the highest attrition rate. To reduce attrition, the bank must focus on customer retention strategies for the "Less than $40K" income group.

# %% [markdown]
# ## Exploring Months Inactive in last 12 month

# %%
target_df = df['Months_Inactive_12_mon'].value_counts().reset_index()
target_df.columns = ['Months_Inactive_12_mon','Count']
print(target_df)
# Out:
#    Months_Inactive_12_mon  Count
# 0                       3   3846
# 1                       2   3282
# 2                       1   2233
# 3                       4    435
# 4                       5    178
# 5                       6    124
# 6                       0     29

# %%
plt.figure(figsize = (15,5))
plt.title("Months Inactive in last 12 month", fontsize = 30)
sns.countplot(x=df['Months_Inactive_12_mon'],hue=df['Attrition_Flag'])
# Out:
# <Axes: title={'center': 'Months Inactive in last 12 month'}, xlabel='Months_Inactive_12_mon', ylabel='count'>

# %%
# Comparing the age distribution vs the target
sns.boxplot(x="Attrition_Flag", y="Months_Inactive_12_mon",
            hue="Attrition_Flag",data=df).set_title("Inactive months vs Churn", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Inactive months vs Churn')

# %% [raw]
# It's evident that the majority of customers have three months of inactivity. It can be concluded that the majority of members who have been inactive for less than three months are non-churning customers.

# %% [markdown]
# ## Comparision

# %% [markdown]
# ### Plotting the Relation Between Credit limit vs. Avg utilization ratio

# %%
sns.lmplot(x='Credit_Limit', y='Avg_Utilization_Ratio', data=df, markers ='.', hue='Attrition_Flag', fit_reg=False, height=5)
plt.title('Relationship Between Credit limit vs. Avg utilization ratio', size=16)
plt.xlabel('Credit limit', size=14) 
plt.ylabel('Avg utilization ratio', size=14)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# There is a negative correlation between credit limit and utilization ratio. Customers with higher credit limits tend to have lower utilization ratios. The customers with higher utilization ratios are more likely to churn. Maintaining a lower utilization ratio seems associated with better retention for the bank.

# %% [markdown]
# ### Plotting the relation between Age and Credit Card limit

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=df, x='Customer_Age', y='Credit_Limit', hue='Attrition_Flag')
plt.title('Relationship Between Age and Credit Limit', size=16)
plt.xlabel('Age', size=14) 
plt.ylabel('Credit Limit', size=14)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Both Existing and churned customers peak average limit around 50 years old. The difference in average limit between Existing and churned widens in the middle age groups before converging again for older customers.

# %% [markdown]
# ## Conclusion from EDA

# %% [markdown]
# Based on the EDA, we can determine that the customer who cancelled their credit card service is a female between the ages of 40 and 50, with a graduate degree, an income below $40K, and three months of inactivity. These factors increase the likelihood of the customer being Churned.

# %% [markdown]
# # Changing the Categorical data value to Numerical Values

# %%
df.Attrition_Flag.unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
Attrition_Flag = df[['Attrition_Flag']]

# Create an instance of the OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Existing Customer', 'Attrited Customer']])

# Fit and transform the data using the encoder
encoded_Attrition_Flag = encoder.fit_transform(Attrition_Flag)

# %%
df['encoded_Attrition_Flag']=encoded_Attrition_Flag.astype(int)

# %%
df[['encoded_Attrition_Flag','Attrition_Flag']].head()
# Out:
#    encoded_Attrition_Flag     Attrition_Flag
# 0                       0  Existing Customer
# 1                       0  Existing Customer
# 2                       0  Existing Customer
# 3                       0  Existing Customer
# 4                       0  Existing Customer

# %%
categorical_columns =['Gender','Education_Level','Marital_Status','Income_Category','Card_Category']
numerical_columns =['Customer_Age', 'Dependent_count',
       'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']

# %% [markdown]
# ## Card Category

# %%
df['Card_Category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
# Sample data with 'Card_Category' column
card_category = df[['Card_Category']]

# Create an instance of the OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Blue', 'Gold', 'Silver','Platinum']])

# Fit and transform the data using the encoder
encoded_card_category = encoder.fit_transform(card_category)

# %%
df['encoded_card_category']=encoded_card_category.astype(int)

# %%
df[['encoded_card_category','Card_Category']].head()
# Out:
#    encoded_card_category Card_Category
# 0                      0          Blue
# 1                      0          Blue
# 2                      0          Blue
# 3                      0          Blue
# 4                      0          Blue

# %% [markdown]
# ## Education_Level

# %%
df['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
# Sample data with 'Card_Category' column
Education_Level = df[['Education_Level']]

# Create an instance of the OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Uneducated','Unknown','High School','College','Graduate','Post-Graduate', 'Doctorate']])

# Fit and transform the data using the encoder
encoded_Education_Level = encoder.fit_transform(Education_Level)

# %%
df['encoded_Education_Level']=encoded_Education_Level.astype(int)

# %%
df[['encoded_Education_Level','Education_Level']].head()
# Out:
#    encoded_Education_Level Education_Level
# 0                        2     High School
# 1                        4        Graduate
# 2                        4        Graduate
# 3                        2     High School
# 4                        0      Uneducated

# %% [markdown]
# ## Income_Category

# %%
df['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
# Sample data with 'Card_Category' column
Income_Category = df[['Income_Category']]

# Create an instance of the OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Unknown', 'Less than $40K','$40K - $60K','$60K - $80K', '$80K - $120K', '$120K +']])

# Fit and transform the data using the encoder
encoded_Income_Category = encoder.fit_transform(Income_Category)

# %%
df['encoded_Income_Category']=encoded_Income_Category.astype(int)

# %%
df[['encoded_Income_Category','Income_Category']].head()
# Out:
#    encoded_Income_Category Income_Category
# 0                        3     $60K - $80K
# 1                        1  Less than $40K
# 2                        4    $80K - $120K
# 3                        1  Less than $40K
# 4                        3     $60K - $80K

# %% [markdown]
# ## Gender

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
Gender=df[['Gender']]

# Using pandas get_dummies() function for one-hot encoding
encoded_Gender = pd.get_dummies(Gender, columns=['Gender'])

# %%
df['Gender_M']=encoded_Gender['Gender_M'].astype(int)

# %%
df[['Gender_M','Gender']].head()
# Out:
#    Gender_M Gender
# 0         1      M
# 1         0      F
# 2         1      M
# 3         0      F
# 4         1      M

# %% [markdown]
# ## Marital Status

# %%
# Sample data with 'Card_Category' column
Marital_Category = df[['Marital_Status']]

# Create an instance of the OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Married', 'Single', 'Unknown', 'Divorced']])

# Fit and transform the data using the encoder
encoded_Marital_Status = encoder.fit_transform(Marital_Category)

# %%
df['encoded_Marital_Status']=encoded_Marital_Status.astype(int)

# %%
df[['encoded_Marital_Status','Marital_Status']].head()
# Out:
#    encoded_Marital_Status Marital_Status
# 0                       0        Married
# 1                       1         Single
# 2                       0        Married
# 3                       2        Unknown
# 4                       0        Married

# %% [markdown]
# ## Dropping colums after converting Categorical Values

# %%
cols_to_drop = ['Attrition_Flag','Gender','Education_Level','Marital_Status','Income_Category','Card_Category']
df_new = df.drop(cols_to_drop, axis=1)

# %%
df_new.head()
# Out:
#    Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 0            45                3              39                         5
# 1            49                5              44                         6
# 2            51                3              36                         4
# 3            40                4              34                         3
# 4            40                3              21                         5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                       1                      3       12691.0
# 1                       1                      2        8256.0
# 2                       1                      0        3418.0
# 3                       4                      1        3313.0
# 4                       1                      0        4716.0
#
#    Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                  777          11914.0                 1.335
# ...

# %% [raw]
# Dropping the Columns 'Attrition_Flag','Gender','Education_Level','Marital_Status','Income_Category','Card_Category' after Converting them from Categorical Value to Numerical Value as string values are not needed for training the models.

# %% [markdown]
# # Correlation between Input and Taget Variable

# %%
plt.figure(figsize=(25, 15))  # You can adjust the figsize as needed

corr_matrix = df_new.corr()

sns.heatmap(corr_matrix, annot=True, xticklabels=corr_matrix.columns, yticklabels=corr_matrix.columns)

plt.show()

# %% [markdown]
# We see above that the following features are not correlated with customer churn:
# 1.Average Open To Buy
# 2.Encoded card category

# %% [markdown]
# ## Dropping the Non Correlated Column

# %%
NCRcols_to_drop = ['Avg_Open_To_Buy','encoded_card_category']
df_new = df_new.drop(NCRcols_to_drop, axis=1)

# %%
df_new
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# 0                45                3              39
# 1                49                5              44
# 2                51                3              36
# 3                40                4              34
# 4                40                3              21
# ...             ...              ...             ...
# 10122            50                2              40
# 10123            41                2              25
# 10124            44                1              36
# 10125            30                2              36
# 10126            43                2              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                             5                       1
# 1                             6                       1
# 2                             4                       1
# 3                             3                       4
# ...

# %% [markdown]
# # Spliting the dataset

# %%
X = df_new.loc[:, df_new.columns != 'encoded_Attrition_Flag']
y = df_new['encoded_Attrition_Flag']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Balancing Over Sampling

# %%
smote_sample = SMOTE(sampling_strategy='minority', k_neighbors=20, random_state=42)
X_train_sm, y_train_sm = smote_sample.fit_resample(X_train, y_train)

# %% [markdown]
# # Decision Trees

# %%
dt = DecisionTreeClassifier()
#fit the tree dt
dt.fit(X_train_sm, y_train_sm)
y_pred1 = dt.predict(X_test)
accuracy = accuracy_score(y_test, y_pred1)
print(f"Decision Tree Accuracy: {accuracy*100:.2f}%")
plt.figure(figsize=(20,10))
plot_tree(dt, filled=True , feature_names=df_new.columns.tolist())
plt.show()
# Out:
# Decision Tree Accuracy: 92.30%

# %%
# Print out the scores
print(f"{'Decision Tree':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred1)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred1)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred1)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred1)}")
# Out:
#   Decision Tree         Score
# ************************************
# Recall Score:     0.8629032258064516
# Accuracy Score:   0.9230009871668312
# Precision Score:  0.7205387205387206
# F1 Score:         0.7853211009174312

# %%
# Print out the classification report
print(classification_report(y_test, y_pred1, target_names=['Attrited Customer', 'Existing Customer']))
# Out:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.97      0.93      0.95      2543
# Existing Customer       0.72      0.86      0.79       496
#
#          accuracy                           0.92      3039
#         macro avg       0.85      0.90      0.87      3039
#      weighted avg       0.93      0.92      0.93      3039

# %% [markdown]
# # Gradient Boosting

# %%
gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=42)
gb.fit(X_train_sm, y_train_sm)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, random_state=42)

# %%
y_pred2 = gb.predict(X_test)
accuracy = accuracy_score(y_test, y_pred2)
print(f"Gradient Boosting Accuracy: {accuracy*100:.2f}%")
# Out:
# Gradient Boosting Accuracy: 94.44%

# %%
# Print out the scores
print(f"{'Gradient Boosting':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred2)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred2)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred2)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred2)}")
# Out:
# Gradient Boosting       Score
# ************************************
# Recall Score:     0.9254032258064516
# Accuracy Score:   0.9443896018427114
# Precision Score:  0.7766497461928934
# F1 Score:         0.8445262189512418

# %%
# Print out the classification report
print(classification_report(y_test, y_pred2, target_names=['Attrited Customer', 'Existing Customer']))
# Out:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.98      0.95      0.97      2543
# Existing Customer       0.78      0.93      0.84       496
#
#          accuracy                           0.94      3039
#         macro avg       0.88      0.94      0.91      3039
#      weighted avg       0.95      0.94      0.95      3039

# %% [markdown]
# # Bagging Classifier

# %%
clf_bc = BaggingClassifier(n_estimators=100,bootstrap=True,random_state=42)
# Fit the bagging classifier model
clf_bc.fit(X_train_sm, y_train_sm)
y_pred5 = clf_bc.predict(X_test)
accuracy = accuracy_score(y_test, y_pred5)
print(f"Bagging Classifier Accuracy: {accuracy*100:.2f}%")
# Out:
# Bagging Classifier Accuracy: 95.23%

# %%
# Print put the scores
print(f"{'Bagging Classifier':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred5)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred5)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred5)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred5)}")
# Out:
# Bagging Classifier      Score
# ************************************
# Recall Score:     0.9092741935483871
# Accuracy Score:   0.9522869364922671
# Precision Score:  0.8185117967332124
# F1 Score:         0.8615090735434575

# %%
# Print out the classification report
print(classification_report(y_test, y_pred5, target_names=['Attrited Customer', 'Existing Customer']))
# Out:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.98      0.96      0.97      2543
# Existing Customer       0.82      0.91      0.86       496
#
#          accuracy                           0.95      3039
#         macro avg       0.90      0.93      0.92      3039
#      weighted avg       0.96      0.95      0.95      3039

# %% [markdown]
# # XG Boost

# %%
clf = xgb.XGBClassifier()
# fit the clf
clf.fit(X_train_sm, y_train_sm)
y_pred3 = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred3)
print(f"XGBoost Accuracy: {accuracy*100:.2f}%")
# Out:
# XGBoost Accuracy: 96.31%

# %%
# Print out the scores
print(f"{'XGBoost':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred3)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred3)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred3)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred3)}")
# Out:
#      XGBoost            Score
# ************************************
# Recall Score:     0.9254032258064516
# Accuracy Score:   0.9631457716354064
# Precision Score:  0.8595505617977528
# F1 Score:         0.8912621359223302

# %%
# Print out the classification report
print(classification_report(y_test, y_pred3, target_names=['Attrited Customer', 'Existing Customer']))
# Out:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.99      0.97      0.98      2543
# Existing Customer       0.86      0.93      0.89       496
#
#          accuracy                           0.96      3039
#         macro avg       0.92      0.95      0.93      3039
#      weighted avg       0.96      0.96      0.96      3039

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestClassifier()
# Fit the random forest
rf.fit(X_train_sm, y_train_sm)
y_pred4 = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred4)
print(f"Random Forest Accuracy: {accuracy*100:.2f}%")
print(f"{'Random Forest':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred4)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred4)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred4)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred4)}")
# Out:
# Random Forest Accuracy: 95.89%
#   Random Forest         Score
# ************************************
# Recall Score:     0.8951612903225806
# Accuracy Score:   0.9588680487002303
# Precision Score:  0.8588007736943907
# F1 Score:         0.8766041461006909

# %%
# Print out the classification report
print(classification_report(y_test, y_pred4, target_names=['Attrited Customer', 'Existing Customer']))
# Out:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.98      0.97      0.98      2543
# Existing Customer       0.86      0.90      0.88       496
#
#          accuracy                           0.96      3039
#         macro avg       0.92      0.93      0.93      3039
#      weighted avg       0.96      0.96      0.96      3039

# %% [markdown]
# # Confusion Matrix

# %%
# Compute confusion matrices 
cm1 = confusion_matrix(y_test, y_pred1)
cm2 = confusion_matrix(y_test, y_pred2)
cm3 = confusion_matrix(y_test, y_pred3)
cm4 = confusion_matrix(y_test, y_pred4)
cm5 = confusion_matrix(y_test, y_pred5)

# Define a function to plot a confusion matrix
def plot_confusion_matrix(cm, title):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(2)  # Assuming binary classification (0 and 1)
    plt.xticks(tick_marks, ['Attrited Customer', 'Existing Customer'])
    plt.yticks(tick_marks, ['Attrited Customer', 'Existing Customer'])
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   
    # Displaying the confusion_matrix values 
    for i in range(2):
        for j in range(2):
            plt.text(j, i, str(cm[i, j]), ha='center', va='center', color='red')

# Create subplots for the confusion matrices
plt.figure(figsize=(15, 10))  # Adjust the figure size as needed

plt.subplot(231)
plot_confusion_matrix(cm1, "Decision Tree")

plt.subplot(232)
plot_confusion_matrix(cm2, "Gradient Boosting")

plt.subplot(233)
plot_confusion_matrix(cm3, "XG Boost")

plt.subplot(234)
plot_confusion_matrix(cm4, "Random Forest")

plt.subplot(235)
plot_confusion_matrix(cm5, "Bagging Classifier")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## Decision Tree

# %%
# Get the defaut model parameters
dt.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# Define the hyperparameter grid
param_grid1 = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}

# %%
# Initialize GridSearchCV for hyperparameter tuning
grid_search1 = GridSearchCV(dt, param_grid=param_grid1, 
                           cv=5)

# %%
# Fit grid_search model
grid_search1.fit(X_train_sm, y_train_sm)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
# Get the best hyperparameters
grid_search1.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
# Make predictions using the best estimator model
best_tree = grid_search1.best_estimator_
y_pred6 = best_tree.predict(X_test)

# %%
# Get the accuracy
accuracy = accuracy_score(y_test, y_pred6)
print(f"Optimized Decision Tree Accuracy: {accuracy*100:.2f}%")
# Out:
# Optimized Decision Tree Accuracy: 93.06%

# %%
# Print out the scores
print(f"{'Optimized Decision Tree':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred6)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred6)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred6)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred6)}")
# Out:
# Optimized Decision Tree      Score
# ************************************
# Recall Score:     0.8649193548387096
# Accuracy Score:   0.9305692662059888
# Precision Score:  0.7486910994764397
# F1 Score:         0.8026192703461178

# %% [markdown]
# ## Feature Importance after parameter tuning

# %%
# Get the importance of each feature
importances1 = dt.feature_importances_

# %%
# Sort the features based on their importance in descending order
indices1 = np.argsort(importances1)[::-1]

# %%
# Visualize Feature Importances
plt.figure(figsize=(12,6))
plt.title("Feature Importances")
plt.bar(range(X_train_sm.shape[1]), importances1[indices1], align="center")
plt.xticks(range(X_train_sm.shape[1]), X_train_sm.columns[indices1], rotation=90)
plt.xlim([-1, X_train_sm.shape[1]])
plt.show()

# %% [markdown]
# ## Gradient Boosting

# %%
# Get the defaut model parameters
gb.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 1.0,
#  'loss': 'log_loss',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': 42,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Define the hyperparameter grid
param_grid2 = {
    'learning_rate': [0.01, 0.1, 1.0],
    'n_estimators': [50, 100],
    'max_depth': [1, 3, 5],
    'min_samples_split': [2, 4],
    'min_samples_leaf': [1, 2],
    'max_features': [None, 'sqrt'],
    'subsample': [0.7, 0.9]
}

# %%
# Initialize GridSearchCV for hyperparameter tuning
grid_search2 = GridSearchCV(gb, param_grid=param_grid2, 
                           cv=5)

# %%
# Fit grid_search model
grid_search2.fit(X_train_sm, y_train_sm)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(learning_rate=1.0,
#                                                   max_depth=1,
#                                                   random_state=42),
#              param_grid={'learning_rate': [0.01, 0.1, 1.0],
#                          'max_depth': [1, 3, 5], 'max_features': [None, 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 4], 'n_estimators': [50, 100],
#                          'subsample': [0.7, 0.9]})

# %%
# Get the best hyperparameters
grid_search2.best_params_
# Out:
# {'learning_rate': 1.0,
#  'max_depth': 5,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100,
#  'subsample': 0.9}

# %%
# Make predictions using the best estimator model
best_gb = grid_search2.best_estimator_
y_pred7 = best_gb.predict(X_test)

# %%
# Get the accuracy
accuracy = accuracy_score(y_test, y_pred7)
print(f"Optimized Gradient Boosting Accuracy: {accuracy*100:.2f}%")
# Out:
# Optimized Gradient Boosting Accuracy: 95.62%

# %%
# Print out the scores
print(f"{'Optimized Gradient Boosting':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred7)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred7)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred7)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred7)}")
# Out:
# Optimized Gradient Boosting      Score
# ************************************
# Recall Score:     0.9012096774193549
# Accuracy Score:   0.9562356038170451
# Precision Score:  0.8418079096045198
# F1 Score:         0.8704965920155793

# %% [markdown]
# ## Feature Importance after parameter tuning

# %%
# Get the importance of each feature
importances2 = gb.feature_importances_

# %%
# Sort the features based on their importance in descending order
indices2 = np.argsort(importances2)[::-1]

# %%
# Visualize Feature Importances
plt.figure(figsize=(12,6))
plt.title("Feature Importances")
plt.bar(range(X_train_sm.shape[1]), importances2[indices2], align="center")
plt.xticks(range(X_train_sm.shape[1]), X_train_sm.columns[indices2], rotation=90)
plt.xlim([-1, X_train_sm.shape[1]])
plt.show()

# %% [markdown]
# ## XG Boost

# %%
# Get the defaut model parameters
clf.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': None,
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
# ...

# %%
# Define the hyperparameter grid
param_grid3 = {
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [50, 100, 200],
    'max_depth': [4, 5, 6],
    'min_child_weight': [1, 2, 4],
    'gamma': [0.1, 0.2, 0.3],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

# %%
# Initialize GridSearchCV for hyperparameter tuning
grid_search3 = GridSearchCV(clf, param_grid=param_grid3, 
                           cv=5)

# %%
# Fit grid_search model
grid_search3.fit(X_train_sm, y_train_sm)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
# ...

# %%
# Get the best hyperparameters
grid_search3.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'gamma': 0.2,
#  'learning_rate': 0.1,
#  'max_depth': 6,
#  'min_child_weight': 1,
#  'n_estimators': 200,
#  'subsample': 0.7}

# %%
# Make predictions using the best estimator model
best_clf = grid_search3.best_estimator_
y_pred8 = best_clf.predict(X_test)

# %%
# Get the accuracy
accuracy = accuracy_score(y_test, y_pred8)
print(f"Optimized XG Boost Accuracy: {accuracy*100:.2f}%")
# Out:
# Optimized XG Boost Accuracy: 96.68%

# %%
# Print out the scores
print(f"{'Optimized XG Boost':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred8)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred8)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred8)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred8)}")
# Out:
# Optimized XG Boost      Score
# ************************************
# Recall Score:     0.9375
# Accuracy Score:   0.9667653833497861
# Precision Score:  0.8691588785046729
# F1 Score:         0.9020368574199806

# %% [markdown]
# ## Feature Importance after parameter tuning

# %%
# Get the importance of each feature
importances3 = clf.feature_importances_

# %%
# Sort the features based on their importance in descending order
indices3 = np.argsort(importances3)[::-1]

# %%
# Visualize Feature Importances
plt.figure(figsize=(12,6))
plt.title("Feature Importances")
plt.bar(range(X_train_sm.shape[1]), importances3[indices3], align="center")
plt.xticks(range(X_train_sm.shape[1]), X_train_sm.columns[indices3], rotation=90)
plt.xlim([-1, X_train_sm.shape[1]])
plt.show()

# %% [markdown]
# ## Random Forest

# %%
# Get the defaut model parameters
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Define the hyperparameter grid
param_grid4 = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
# Initialize GridSearchCV for hyperparameter tuning
grid_search4 = GridSearchCV(estimator=rf, param_grid=param_grid4, 
                           cv=5)

# %%
# Fit grid_search model
grid_search4.fit(X_train_sm, y_train_sm)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 200]})

# %%
# Get the best hyperparameters
grid_search4.best_params_
# Out:
# {'max_depth': 30,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
# Make predictions using the best estimator model
best_rf = grid_search4.best_estimator_
y_pred9 = best_rf.predict(X_test)

# %%
# Get the accuracy
accuracy = accuracy_score(y_test, y_pred9)
print(f"Optimized Random Forest Accuracy: {accuracy*100:.2f}%")
# Out:
# Optimized Random Forest Accuracy: 95.62%

# %%
# Print out the scores
print(f"{'Optimized Random Forest':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred9)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred9)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred9)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred9)}")
# Out:
# Optimized Random Forest      Score
# ************************************
# Recall Score:     0.8951612903225806
# Accuracy Score:   0.9562356038170451
# Precision Score:  0.8457142857142858
# F1 Score:         0.8697355533790402

# %% [markdown]
# ## Feature Importance after parameter tuning

# %%
# Get the importance of each feature
importances4 = rf.feature_importances_

# %%
# Sort the features based on their importance in descending order
indices4 = np.argsort(importances4)[::-1]

# %%
# Visualize Feature Importances
plt.figure(figsize=(12,6))
plt.title("Feature Importances")
plt.bar(range(X_train_sm.shape[1]), importances4[indices4], align="center")
plt.xticks(range(X_train_sm.shape[1]), X_train_sm.columns[indices4], rotation=90)
plt.xlim([-1, X_train_sm.shape[1]])
plt.show()

# %% [markdown]
# ## Bagging Classifier

# %%
# Get the defaut model parameters
clf_bc.get_params()
# Out:
# {'base_estimator': 'deprecated',
#  'bootstrap': True,
#  'bootstrap_features': False,
#  'estimator': None,
#  'max_features': 1.0,
#  'max_samples': 1.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Define the hyperparameter grid
param_grid5 = {
    'n_estimators': [10, 50, 100, 200],
    'max_samples': [0.5, 0.9, 1.0],
    'max_features': [0.5, 0.9, 1.0],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False]
}

# %%
# Initialize GridSearchCV for hyperparameter tuning
grid_search5 = GridSearchCV(clf_bc, param_grid=param_grid5, 
                           cv=5)

# %%
# Fit grid_search model
grid_search5.fit(X_train_sm, y_train_sm)
# Out:
# GridSearchCV(cv=5,
#              estimator=BaggingClassifier(n_estimators=100, random_state=42),
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'max_features': [0.5, 0.9, 1.0],
#                          'max_samples': [0.5, 0.9, 1.0],
#                          'n_estimators': [10, 50, 100, 200]})

# %%
# Get the best hyperparameters
grid_search5.best_params_
# Out:
# {'bootstrap': False,
#  'bootstrap_features': False,
#  'max_features': 0.5,
#  'max_samples': 1.0,
#  'n_estimators': 200}

# %%
# Make predictions using the best estimator model
best_clf_bc = grid_search5.best_estimator_
y_pred10 = best_clf_bc.predict(X_test)

# %%
# Get the accuracy
accuracy = accuracy_score(y_test, y_pred10)
print(f"Optimized Bagging Classifier Accuracy: {accuracy*100:.2f}%")
# Out:
# Optimized Bagging Classifier Accuracy: 96.15%

# %%
# Print out the scores
print(f"{'Optimized Bagging Classifier':^18}{'Score':^18}")
print("************************************")
print(f"{'Recall Score:':18}{recall_score(y_test, y_pred10)}")
print(f"{'Accuracy Score: ':18}{accuracy_score(y_test, y_pred10)}")
print(f"{'Precision Score: ':18}{precision_score(y_test, y_pred10)}")
print(f"{'F1 Score: ':18}{f1_score(y_test, y_pred10)}")
# Out:
# Optimized Bagging Classifier      Score
# ************************************
# Recall Score:     0.8608870967741935
# Accuracy Score:   0.9615004935834156
# Precision Score:  0.8989473684210526
# F1 Score:         0.8795056642636457

# %% [markdown]
# ## Feature Importance after parameter tuning

# %%
# Get the importance of each feature
importances5 = np.mean([
    tree.feature_importances_ for tree in clf_bc.estimators_
], axis=0)

# %%
# Sort the features based on their importance in descending order
indices5 = np.argsort(importances5)[::-1]

# %%
# Visualize Feature Importances
plt.figure(figsize=(12,6))
plt.title("Feature Importances")
plt.bar(range(X_train_sm.shape[1]), importances5[indices5], align="center")
plt.xticks(range(X_train_sm.shape[1]), X_train_sm.columns[indices5], rotation=90)
plt.xlim([-1, X_train_sm.shape[1]])
plt.show()

# %% [markdown]
# # Model Performance & Conclusion

# %% [markdown]
# Based on the evaluation metrics:
#
# Optimized XGBoost performed the best with the highest recall (0.9375), accuracy (0.9668), and F1-score (0.9020), making it the most effective model for predicting churn.
#
# Optimized Gradient Boosting and Optimized Random Forest also performed well, but XGBoost showed superior balance between precision and recall.
#
# Optimized Bagging Classifier had a strong precision score but slightly lower recall.
#
# Optimized Decision Tree had the lowest precision and F1-score among the models.
#
# Thus, XGBoost is recommended as the best model for churn prediction in this dataset.
